# %%
import matplotlib.pyplot as plt  # 绘图用的模块
from mpl_toolkits.mplot3d import Axes3D  # 绘制3D坐标的函数
import numpy as np

def fun(x, y):
    return np.power(x, 2) + np.power(y, 2)
fig1 = plt.figure()  # 创建一个绘图对象
ax = Axes3D(fig1)  # 用这个绘图对象创建一个Axes对象(有3D坐标)
X, Y = np.mgrid[-2:2:40j, -2:2:40j]  # 从-2到2分别生成40个取样坐标，并作满射联合
Z = fun(X, Y)  # 用取样点横纵坐标去求取样点Z坐标
plt.title("This is main title")  # 总标题
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, alpha=0.5)  # 用取样点(x,y,z)去构建曲面
ax.set_xlabel('x label', color='r')
ax.set_ylabel('y label', color='g')
ax.set_zlabel('z label', color='b')  # 给三个坐标轴注明
plt.show()  # 显示模块中的所有绘图对象

# %%
import matplotlib.pyplot as plt  # 绘图用的模块
from mpl_toolkits.mplot3d import Axes3D  # 绘制3D坐标的函数
import numpy as np
from pylab import mpl 
mpl.rcParams['font.sans-serif']=['SimHei']   # 修改为中文字体

plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签
plt.rcParams['axes.unicode_minus']=False

# %%
# 定义函数
def fun(x1, x2):
    return (1 + np.sin(2* x1 + 3 * x2))/(3.5 + np.sin(x1 -x2))

# 生成数据
x1 = np.linspace(-2, 2, 500)
x2 = x1
x1, x2 = np.meshgrid(x1, x2)
y = fun(x1, x2)

# %%
fig = plt.figure(figsize=(8,5))
ax = Axes3D(fig)
plt.title(r'$y=\frac{1+\sin(2x_1+3x_2)}{3.5+\sin(x_1-x_2)}$')
ax.plot_surface(x1, x2, y, rstride=1, cstride=1, cmap=plt.cm.coolwarm, alpha=0.5)
ax.set_xlabel(r'$x_1$', color='r')
ax.set_ylabel(r'$x_2$', color='g')
ax.set_zlabel(r'$y$', color='b')  # 给三个坐标轴注明
plt.show()  # 显示模块中的所有绘图对象
fig.savefig('functionfig.png', dpi=900)
# Out:
# C:\Users\zhouz\AppData\Local\Temp/ipykernel_12144/973603886.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
